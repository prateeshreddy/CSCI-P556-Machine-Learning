# %% [markdown]
# # Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np
import sys
import torch
import torchvision
from sklearn.metrics import confusion_matrix
from sklearn.decomposition import PCA

# %%
def get_device(use_gpu=True):
    return torch.device("cuda" if torch.cuda.is_available() and use_gpu else "cpu")

def to_device(items, device):
    return [item.to(device) for item in items]

def to_tensor(items, types):
    tensors = []
    for i in range(len(items)):
        if isinstance(items[i], torch.Tensor):
            tensors += items[i]
        elif isinstance(items[i], np.ndarray):
            if isinstance(types, list):
                tensors += [torch.tensor(items[i], dtype=types[i])]
            else:
                tensors += [torch.tensor(items[i], dtype=types)]
        else:
            raise NotImplementedError()
    return tensors

def to_ndarray(items):
    ndarrays = []
    for item in items:
        if isinstance(item, torch.Tensor):
            ndarrays += [item.detach().cpu().numpy()]
        elif isinstance(item, np.ndarray):
            ndarrays += [item]
        elif isinstance(item, list):
            ndarrays += [np.array(item)]
        else:
            raise NotImplementedError()
    return ndarrays

def get_accuracy(Yhat, Y):
    if isinstance(Yhat, torch.Tensor) and isinstance(Y, torch.Tensor):
        _, preds = Yhat.max(dim=1)
        n_correct = preds.eq(Y).sum().item()
    elif isinstance(Yhat, np.ndarray) and isinstance(Y, np.ndarray):
        preds = np.argmax(Yhat, axis=-1)
        n_correct = len(np.where(preds == Y)[0])
    return n_correct / len(Y) * 100

def get_confusion(Yhat, Y):
    preds = np.argmax(Yhat, axis=-1)
    return confusion_matrix(Y, preds)

def plot_model_accuracies(model, show=[1,2,3], ylim=[95, 100.1]):
    plt.figure(figsize=(15,10))
    if 1 in show:
        plt.plot(model.train_accs, color="k", label="training")
    if 2 in show:
        plt.plot(model.valid_accs, color="r", label="validation")
    if 3 in show:
        plt.plot(model.test_accs, color="g", label="testing")
    plt.ylabel("Accuracy")
    plt.xlabel("Epoch")
    plt.ylim(ylim[0], ylim[1])
    plt.xlim(-1, len(model.train_accs)+1)
    plt.legend()
    plt.show()
    plt.close()
    
def plot_model_losses(model, show=[1,2,3], ylim=[0, 3]):
    plt.figure(figsize=(15,10))
    if 1 in show:
        plt.plot(model.train_losses, color="k", label="training")
    if 2 in show:
        plt.plot(model.valid_losses, color="r", label="validation")
    if 3 in show:
        plt.plot(model.test_losses, color="g", label="testing")
    plt.ylabel("Cross Entropy Loss")
    plt.xlabel("Epoch")
    plt.ylim(ylim[0], ylim[1])
    plt.xlim(-1, len(model.train_accs)+1)
    plt.legend()
    plt.show()
    plt.close()
    
def plot_confusion(Yhat, Y):
    n_classes = np.unique(Y).shape[0]
    mat = get_confusion(test_Yhat, test_Y)
    plt.figure(figsize=(10,10))
    plt.imshow(mat, extent=[-0.5, n_classes-1+0.5, -0.5, n_classes-1+0.5], origin="upper")
    plt.ylabel("True Class")
    plt.title("Predicted Class")
    plt.yticks(np.arange(n_classes))
    plt.xticks(np.arange(n_classes))
    for j in range(mat.shape[0]):
        for k in range(mat.shape[1]):
            plt.text(j, k, mat[mat.shape[0]-k-1,j], ha="center", va="center")
    plt.show()
    plt.close()

act_func_map = {
    "relu": torch.nn.functional.relu, 
    "tanh": torch.nn.functional.tanh, 
    "sigmoid": torch.sigmoid, 
    "identity": lambda x:x,
    "log_softmax": torch.nn.functional.log_softmax,
}
opt_func_map = {
    "sgd": torch.optim.SGD, 
    "adam": torch.optim.Adam
}
init_func_map = {
    "constant": torch.nn.init.constant_,
    "normal": torch.nn.init.normal_, 
    "xavier": torch.nn.init.xavier_normal_, 
    "kaiming": torch.nn.init.kaiming_normal_,
}
loss_func_map = {
    "mae": torch.nn.L1Loss, 
    "mse": torch.nn.MSELoss, 
    "smooth_mae": torch.nn.SmoothL1Loss,
    "nll": torch.nn.NLLLoss,
}

# %%
train = torchvision.datasets.MNIST(
    "data",
    train=True,
    download=True
)
test = torchvision.datasets.MNIST(
    "data",
    train=False,
    download=True
)
train_X = train.data.numpy()
train_Y = train.targets.numpy()
np.random.seed(123)
selection = np.random.choice(train_X.shape[0], size=train_X.shape[0]//10, replace=False)
valid_X = train_X[selection,:]
valid_Y = train_Y[selection]
train_X = np.delete(train_X, selection, axis=0)
train_Y = np.delete(train_Y, selection, axis=0)
test_X = test.data.numpy()
test_Y = test.targets.numpy()
train_X = np.reshape(train_X, (train_X.shape[0], 1, train_X.shape[1], train_X.shape[2]))
valid_X = np.reshape(valid_X, (valid_X.shape[0], 1, valid_X.shape[1], valid_X.shape[2]))
test_X = np.reshape(test_X, (test_X.shape[0], 1, test_X.shape[1], test_X.shape[2]))
print(train_X.shape)
print(train_Y.shape)
print(valid_X.shape)
print(valid_Y.shape)
print(test_X.shape)
print(test_Y.shape)
train_X = (train_X / 255 - 0.5) * 2
valid_X = (valid_X / 255 - 0.5) * 2
test_X = (test_X / 255 - 0.5) * 2
n_channels, height, width = train_X.shape[1], train_X.shape[2], train_X.shape[3]
n_classes = len(np.unique(train_Y))
# Out:
# (54000, 1, 28, 28)
# (54000,)
# (6000, 1, 28, 28)
# (6000,)
# (10000, 1, 28, 28)
# (10000,)

# %%
class CNN(torch.nn.Module):
    
    def __init__(self, n_channels, height, width, n_responses, dropout=0.25):
        super(CNN, self).__init__()
        in_width, in_width, = height, width
        in_channels, out_channels = n_channels, 12
        kernel_size, stride = (5, 5), (2, 2)
        self.layer_1 = torch.nn.Conv2d(in_channels, out_channels, kernel_size, stride)
        in_width, in_height = self.get_conv2d_output_heightwidth(in_channels, out_channels, kernel_size, stride)
        self.layer_2 = torch.nn.Dropout(dropout)
        in_channels, out_channels = out_channels, 12
        kernel_size, stride = (5, 5), (2, 2)
        self.layer_3 = torch.nn.Conv2d(in_channels, out_channels, kernel_size, stride)
        in_width, in_height = self.get_conv2d_output_heightwidth(in_channels, out_channels, kernel_size, stride)
        self.layer_4 = torch.nn.Dropout(dropout)
        in_channels = out_channels
        self.layer_5 = torch.nn.Flatten()
        self.layer_6 = torch.nn.Linear(in_channels*in_width*in_height, 30)
        self.layer_7 = torch.nn.Dropout(dropout)
        self.layer_8 = torch.nn.Linear(30, n_responses)
        
    def forward(self, X):
        a = X
        z = self.layer_1(a)
        a = act_func_map["relu"](z)
        z = self.layer_2(a)
        a = act_func_map["identity"](z)
        z = self.layer_3(a)
        a = act_func_map["relu"](z)
        z = self.layer_4(a)
        a = act_func_map["identity"](z)
        z = self.layer_5(a)
        a = act_func_map["identity"](z)
        z = self.layer_6(a)
        a = act_func_map["relu"](z)
        z = self.layer_7(a)
        a = act_func_map["identity"](z)
        z = self.layer_8(a)
        a = act_func_map["log_softmax"](z, dim=1)
        return a
    
    def optimize(self, train, valid=None, test=None, lr=0.05, mo=0.9, early_stop_epochs=10, n_epochs=100, mbatch_size=256, 
                 loss="nll", opt="sgd", batch_shuf_seed=1, init="xavier", init_seed=1):
        device = get_device()
        self = to_device([self], device)[0]
        train = to_device(to_tensor(train, [torch.float, torch.long]), device)
        train_X, train_Y = train[0], train[1]
        if valid is not None:
            valid = to_device(to_tensor(valid, [torch.float, torch.long]), device)
            valid_X, valid_Y = valid[0], valid[1]
        if test is not None:
            test = to_device(to_tensor(test, [torch.float, torch.long]), device)
            test_X, test_Y = test[0], test[1]
        # Initialize loss, optimizer, and parameters
        self.crit = loss_func_map[loss]()
        if opt == "adam":
            self.opt = opt_func_map[opt](self.parameters(), lr=lr, betas=(mo, 0.999))
        if opt == "sgd":
            self.opt = opt_func_map[opt](self.parameters(), lr=lr, momentum=mo)
        self.init_params(init, init_seed)
        # Commence optimization
        n_mbatches = train_X.shape[0] // mbatch_size
        if batch_shuf_seed > -1:
            np.random.seed(batch_shuf_seed)
        self.train_losses, self.valid_losses, self.test_losses = [], [], []
        self.train_accs, self.valid_accs, self.test_accs = [], [], []
        min_valid_loss, max_valid_acc = sys.float_info.max, sys.float_info.min
        n_plateau_epochs = 0
        for epoch in range(n_epochs+1):
            selection = np.random.choice(train_X.shape[0], size=train_X.shape[0], replace=False)
            train_loss = 0
            self.train()
            # Step through minibatches
            for mbatch in range(n_mbatches):
                start = mbatch * mbatch_size
                end = (mbatch + 1) * mbatch_size
                mbatch_loss = self.crit(self(train_X[selection[start:end]]), train_Y[selection[start:end]])
                # Gradient descent step
                self.opt.zero_grad()
                mbatch_loss.backward()
                self.opt.step()
                train_loss += mbatch_loss.item()
            train_loss /= n_mbatches
            self.eval()
            train_acc = get_accuracy(self(train_X), train_Y)
            print("Epoch %d : Training Loss/Accuracy   = %.3f/%.3f" % (epoch, train_loss, train_acc))
            self.train_losses += [train_loss]
            self.train_accs += [train_acc]
            if valid is not None:
                valid_Yhat = self(valid_X)
                valid_loss = self.crit(valid_Yhat, valid_Y).item()
                valid_acc = get_accuracy(valid_Yhat, valid_Y)
                print("Epoch %d : Validation Loss/Accuracy = %.3f/%.3f" % (epoch, valid_loss, valid_acc))
                self.valid_losses += [valid_loss]
                self.valid_accs += [valid_acc]
                if valid_acc <= max_valid_acc:
                    n_plateau_epochs += 1
                else:
                    n_plateau_epochs = 0
                    max_valid_acc = valid_acc
            if test is not None:
                test_Yhat = self(test_X)
                test_loss = self.crit(test_Yhat, test_Y).item()
                test_acc = get_accuracy(test_Yhat, test_Y)
                print("Epoch %d : Testing Loss/Accuracy    = %.3f/%.3f" % (epoch, test_loss, test_acc))
                self.test_losses += [test_loss]
                self.test_accs += [test_acc]
            for param_group in self.opt.param_groups:
                param_group["lr"] = lr * 0.9**(epoch//10)
            print("############################################################")
            if n_plateau_epochs >= early_stop_epochs:
                print("Stopping early!")
                break
        device = get_device(False)
        self = to_device([self], device)[0]
        train = to_ndarray(train)
        if valid is not None:
            valid = to_ndarray(valid)
        if test is not None:
            test = to_ndarray(test)
            
    def predict(self, X):
        self.eval()
        device = get_device()
        self = to_device([self], device)[0]
        X = to_device(to_tensor([X], [torch.float]), device)[0]
        Yhat = self(X)
        device = get_device(False)
        self = to_device([self], device)[0]
        data = to_ndarray([X, Yhat])
        X, Yhat = data[0], data[1]
        return Yhat
    
    def init_params(self, init, seed=-1):
        if seed > -1:
            torch.manual_seed(seed)
        for name, param in self.named_parameters():
            if "bias" in name:
                init_func_map["constant"](param, 0.0)
            elif "weight" in name:
                init_func_map[init](param)
    
    def get_conv2d_output_heightwidth(self, H_in, W_in, kernel_size, stride, padding=(0, 0), dilation=(1, 1)):
        H_out = int((H_in + 2 * padding[0] - dilation[0] * (kernel_size[0] - 1) - 1) / stride[0] + 1)
        W_out = int((W_in + 2 * padding[1] - dilation[1] * (kernel_size[1] - 1) - 1) / stride[1] + 1)
        return H_out, W_out

# %%
model = CNN(n_channels, height, width, n_classes)
model.optimize([train_X, train_Y], [valid_X, valid_Y], [test_X, test_Y], mbatch_size=1024)
# Out:
# Epoch 0 : Training Loss/Accuracy   = 1.415/86.128
# Epoch 0 : Validation Loss/Accuracy = 0.435/86.067
# Epoch 0 : Testing Loss/Accuracy    = 0.415/86.970
# ############################################################
# Epoch 1 : Training Loss/Accuracy   = 0.575/92.611
# Epoch 1 : Validation Loss/Accuracy = 0.255/92.667
# Epoch 1 : Testing Loss/Accuracy    = 0.236/93.370
# ############################################################
# Epoch 2 : Training Loss/Accuracy   = 0.436/94.493
# Epoch 2 : Validation Loss/Accuracy = 0.193/94.483
# Epoch 2 : Testing Loss/Accuracy    = 0.180/95.000
# ############################################################
# Epoch 3 : Training Loss/Accuracy   = 0.364/95.554
# Epoch 3 : Validation Loss/Accuracy = 0.154/95.500
# Epoch 3 : Testing Loss/Accuracy    = 0.145/95.800
# ############################################################
# Epoch 4 : Training Loss/Accuracy   = 0.316/96.000
# Epoch 4 : Validation Loss/Accuracy = 0.131/95.900
# Epoch 4 : Testing Loss/Accuracy    = 0.120/96.320
# ############################################################
# Epoch 5 : Training Loss/Accuracy   = 0.287/96.465
# Epoch 5 : Validation Loss/Accuracy = 0.121/96.317
# Epoch 5 : Testing Loss/Accuracy    = 0.110/96.700
# ############################################################
# Epoch 6 : Training Loss/Accuracy   = 0.256/96.891
# Epoch 6 : Validation Loss/Accuracy = 0.106/96.733
# Epoch 6 : Testing Loss/Accuracy    = 0.096/97.000
# ############################################################
# Epoch 7 : Training Loss/Accuracy   = 0.243/97.098
# Epoch 7 : Validation Loss/Accuracy = 0.101/96.733
# Epoch 7 : Testing Loss/Accuracy    = 0.088/97.330
# ############################################################
# Epoch 8 : Training Loss/Accuracy   = 0.226/97.206
# Epoch 8 : Validation Loss/Accuracy = 0.099/96.983
# Epoch 8 : Testing Loss/Accuracy    = 0.084/97.350
# ############################################################
# Epoch 9 : Training Loss/Accuracy   = 0.214/97.506
# Epoch 9 : Validation Loss/Accuracy = 0.088/97.050
# Epoch 9 : Testing Loss/Accuracy    = 0.075/97.790
# ############################################################
# Epoch 10 : Training Loss/Accuracy   = 0.208/97.715
# Epoch 10 : Validation Loss/Accuracy = 0.084/97.250
# Epoch 10 : Testing Loss/Accuracy    = 0.072/97.880
# ############################################################
# Epoch 11 : Training Loss/Accuracy   = 0.196/97.815
# Epoch 11 : Validation Loss/Accuracy = 0.079/97.383
# Epoch 11 : Testing Loss/Accuracy    = 0.070/97.900
# ############################################################
# Epoch 12 : Training Loss/Accuracy   = 0.187/97.898
# Epoch 12 : Validation Loss/Accuracy = 0.076/97.483
# Epoch 12 : Testing Loss/Accuracy    = 0.067/97.960
# ############################################################
# Epoch 13 : Training Loss/Accuracy   = 0.181/97.917
# Epoch 13 : Validation Loss/Accuracy = 0.074/97.533
# Epoch 13 : Testing Loss/Accuracy    = 0.066/98.070
# ############################################################
# Epoch 14 : Training Loss/Accuracy   = 0.178/98.039
# Epoch 14 : Validation Loss/Accuracy = 0.070/97.750
# Epoch 14 : Testing Loss/Accuracy    = 0.061/98.160
# ############################################################
# Epoch 15 : Training Loss/Accuracy   = 0.175/98.039
# Epoch 15 : Validation Loss/Accuracy = 0.072/97.717
# Epoch 15 : Testing Loss/Accuracy    = 0.060/98.180
# ############################################################
# Epoch 16 : Training Loss/Accuracy   = 0.171/98.094
# Epoch 16 : Validation Loss/Accuracy = 0.072/97.633
# Epoch 16 : Testing Loss/Accuracy    = 0.061/98.110
# ############################################################
# Epoch 17 : Training Loss/Accuracy   = 0.165/98.144
# Epoch 17 : Validation Loss/Accuracy = 0.069/97.700
# Epoch 17 : Testing Loss/Accuracy    = 0.059/98.140
# ############################################################
# Epoch 18 : Training Loss/Accuracy   = 0.164/98.176
# Epoch 18 : Validation Loss/Accuracy = 0.065/97.867
# Epoch 18 : Testing Loss/Accuracy    = 0.057/98.200
# ############################################################
# Epoch 19 : Training Loss/Accuracy   = 0.158/98.289
# Epoch 19 : Validation Loss/Accuracy = 0.063/97.850
# Epoch 19 : Testing Loss/Accuracy    = 0.054/98.250
# ############################################################
# Epoch 20 : Training Loss/Accuracy   = 0.157/98.259
# Epoch 20 : Validation Loss/Accuracy = 0.064/97.800
# Epoch 20 : Testing Loss/Accuracy    = 0.056/98.220
# ############################################################
# Epoch 21 : Training Loss/Accuracy   = 0.155/98.385
# Epoch 21 : Validation Loss/Accuracy = 0.060/97.900
# Epoch 21 : Testing Loss/Accuracy    = 0.052/98.330
# ############################################################
# Epoch 22 : Training Loss/Accuracy   = 0.150/98.389
# Epoch 22 : Validation Loss/Accuracy = 0.059/98.017
# Epoch 22 : Testing Loss/Accuracy    = 0.051/98.340
# ############################################################
# Epoch 23 : Training Loss/Accuracy   = 0.151/98.424
# Epoch 23 : Validation Loss/Accuracy = 0.058/98.100
# Epoch 23 : Testing Loss/Accuracy    = 0.051/98.310
# ############################################################
# Epoch 24 : Training Loss/Accuracy   = 0.146/98.389
# Epoch 24 : Validation Loss/Accuracy = 0.058/98.067
# Epoch 24 : Testing Loss/Accuracy    = 0.050/98.350
# ############################################################
# Epoch 25 : Training Loss/Accuracy   = 0.146/98.422
# Epoch 25 : Validation Loss/Accuracy = 0.055/98.150
# Epoch 25 : Testing Loss/Accuracy    = 0.050/98.430
# ############################################################
# Epoch 26 : Training Loss/Accuracy   = 0.141/98.380
# Epoch 26 : Validation Loss/Accuracy = 0.062/98.083
# Epoch 26 : Testing Loss/Accuracy    = 0.052/98.410
# ############################################################
# Epoch 27 : Training Loss/Accuracy   = 0.142/98.393
# Epoch 27 : Validation Loss/Accuracy = 0.061/97.950
# Epoch 27 : Testing Loss/Accuracy    = 0.050/98.390
# ############################################################
# Epoch 28 : Training Loss/Accuracy   = 0.140/98.598
# Epoch 28 : Validation Loss/Accuracy = 0.053/98.183
# Epoch 28 : Testing Loss/Accuracy    = 0.046/98.560
# ############################################################
# Epoch 29 : Training Loss/Accuracy   = 0.137/98.576
# Epoch 29 : Validation Loss/Accuracy = 0.052/98.433
# Epoch 29 : Testing Loss/Accuracy    = 0.046/98.370
# ############################################################
# Epoch 30 : Training Loss/Accuracy   = 0.139/98.539
# Epoch 30 : Validation Loss/Accuracy = 0.057/98.033
# Epoch 30 : Testing Loss/Accuracy    = 0.048/98.480
# ############################################################
# Epoch 31 : Training Loss/Accuracy   = 0.138/98.591
# Epoch 31 : Validation Loss/Accuracy = 0.053/98.283
# Epoch 31 : Testing Loss/Accuracy    = 0.045/98.540
# ############################################################
# Epoch 32 : Training Loss/Accuracy   = 0.130/98.626
# Epoch 32 : Validation Loss/Accuracy = 0.051/98.300
# Epoch 32 : Testing Loss/Accuracy    = 0.045/98.470
# ############################################################
# Epoch 33 : Training Loss/Accuracy   = 0.130/98.635
# Epoch 33 : Validation Loss/Accuracy = 0.051/98.450
# Epoch 33 : Testing Loss/Accuracy    = 0.044/98.480
# ############################################################
# Epoch 34 : Training Loss/Accuracy   = 0.128/98.656
# Epoch 34 : Validation Loss/Accuracy = 0.050/98.317
# Epoch 34 : Testing Loss/Accuracy    = 0.044/98.550
# ############################################################
# Epoch 35 : Training Loss/Accuracy   = 0.127/98.626
# Epoch 35 : Validation Loss/Accuracy = 0.054/98.350
# Epoch 35 : Testing Loss/Accuracy    = 0.045/98.530
# ############################################################
# Epoch 36 : Training Loss/Accuracy   = 0.127/98.706
# Epoch 36 : Validation Loss/Accuracy = 0.050/98.367
# Epoch 36 : Testing Loss/Accuracy    = 0.043/98.670
# ############################################################
# Epoch 37 : Training Loss/Accuracy   = 0.126/98.626
# Epoch 37 : Validation Loss/Accuracy = 0.055/98.200
# Epoch 37 : Testing Loss/Accuracy    = 0.045/98.590
# ############################################################
# Epoch 38 : Training Loss/Accuracy   = 0.125/98.680
# Epoch 38 : Validation Loss/Accuracy = 0.049/98.417
# Epoch 38 : Testing Loss/Accuracy    = 0.043/98.500
# ############################################################
# Epoch 39 : Training Loss/Accuracy   = 0.125/98.706
# Epoch 39 : Validation Loss/Accuracy = 0.051/98.500
# Epoch 39 : Testing Loss/Accuracy    = 0.044/98.610
# ############################################################
# Epoch 40 : Training Loss/Accuracy   = 0.125/98.730
# Epoch 40 : Validation Loss/Accuracy = 0.050/98.400
# Epoch 40 : Testing Loss/Accuracy    = 0.043/98.560
# ############################################################
# Epoch 41 : Training Loss/Accuracy   = 0.126/98.694
# Epoch 41 : Validation Loss/Accuracy = 0.051/98.450
# Epoch 41 : Testing Loss/Accuracy    = 0.044/98.570
# ############################################################
# Epoch 42 : Training Loss/Accuracy   = 0.123/98.746
# Epoch 42 : Validation Loss/Accuracy = 0.048/98.533
# Epoch 42 : Testing Loss/Accuracy    = 0.042/98.650
# ############################################################
# Epoch 43 : Training Loss/Accuracy   = 0.120/98.819
# Epoch 43 : Validation Loss/Accuracy = 0.046/98.500
# Epoch 43 : Testing Loss/Accuracy    = 0.041/98.590
# ############################################################
# Epoch 44 : Training Loss/Accuracy   = 0.126/98.737
# Epoch 44 : Validation Loss/Accuracy = 0.049/98.383
# Epoch 44 : Testing Loss/Accuracy    = 0.043/98.690
# ############################################################
# Epoch 45 : Training Loss/Accuracy   = 0.118/98.765
# Epoch 45 : Validation Loss/Accuracy = 0.049/98.450
# Epoch 45 : Testing Loss/Accuracy    = 0.042/98.670
# ############################################################
# Epoch 46 : Training Loss/Accuracy   = 0.119/98.872
# Epoch 46 : Validation Loss/Accuracy = 0.045/98.533
# Epoch 46 : Testing Loss/Accuracy    = 0.040/98.620
# ############################################################
# Epoch 47 : Training Loss/Accuracy   = 0.118/98.817
# Epoch 47 : Validation Loss/Accuracy = 0.047/98.450
# Epoch 47 : Testing Loss/Accuracy    = 0.039/98.730
# ############################################################
# Epoch 48 : Training Loss/Accuracy   = 0.119/98.843
# Epoch 48 : Validation Loss/Accuracy = 0.046/98.550
# Epoch 48 : Testing Loss/Accuracy    = 0.040/98.690
# ############################################################
# Epoch 49 : Training Loss/Accuracy   = 0.117/98.824
# Epoch 49 : Validation Loss/Accuracy = 0.046/98.467
# Epoch 49 : Testing Loss/Accuracy    = 0.040/98.640
# ############################################################
# Epoch 50 : Training Loss/Accuracy   = 0.117/98.828
# Epoch 50 : Validation Loss/Accuracy = 0.046/98.533
# Epoch 50 : Testing Loss/Accuracy    = 0.040/98.700
# ############################################################
# Epoch 51 : Training Loss/Accuracy   = 0.115/98.804
# Epoch 51 : Validation Loss/Accuracy = 0.045/98.567
# Epoch 51 : Testing Loss/Accuracy    = 0.040/98.690
# ############################################################
# Epoch 52 : Training Loss/Accuracy   = 0.113/98.874
# Epoch 52 : Validation Loss/Accuracy = 0.045/98.550
# Epoch 52 : Testing Loss/Accuracy    = 0.039/98.780
# ############################################################
# Epoch 53 : Training Loss/Accuracy   = 0.114/98.828
# Epoch 53 : Validation Loss/Accuracy = 0.048/98.567
# Epoch 53 : Testing Loss/Accuracy    = 0.040/98.680
# ############################################################
# Epoch 54 : Training Loss/Accuracy   = 0.114/98.885
# Epoch 54 : Validation Loss/Accuracy = 0.045/98.600
# Epoch 54 : Testing Loss/Accuracy    = 0.039/98.690
# ############################################################
# Epoch 55 : Training Loss/Accuracy   = 0.116/98.841
# Epoch 55 : Validation Loss/Accuracy = 0.047/98.467
# Epoch 55 : Testing Loss/Accuracy    = 0.039/98.780
# ############################################################
# Epoch 56 : Training Loss/Accuracy   = 0.112/98.872
# Epoch 56 : Validation Loss/Accuracy = 0.045/98.583
# Epoch 56 : Testing Loss/Accuracy    = 0.038/98.730
# ############################################################
# Epoch 57 : Training Loss/Accuracy   = 0.110/98.874
# Epoch 57 : Validation Loss/Accuracy = 0.045/98.517
# Epoch 57 : Testing Loss/Accuracy    = 0.038/98.650
# ############################################################
# Epoch 58 : Training Loss/Accuracy   = 0.113/98.885
# Epoch 58 : Validation Loss/Accuracy = 0.045/98.533
# Epoch 58 : Testing Loss/Accuracy    = 0.038/98.800
# ############################################################
# Epoch 59 : Training Loss/Accuracy   = 0.111/98.915
# Epoch 59 : Validation Loss/Accuracy = 0.043/98.533
# Epoch 59 : Testing Loss/Accuracy    = 0.038/98.750
# ############################################################
# Epoch 60 : Training Loss/Accuracy   = 0.108/98.848
# Epoch 60 : Validation Loss/Accuracy = 0.046/98.533
# Epoch 60 : Testing Loss/Accuracy    = 0.040/98.630
# ############################################################
# Epoch 61 : Training Loss/Accuracy   = 0.110/98.933
# Epoch 61 : Validation Loss/Accuracy = 0.043/98.683
# Epoch 61 : Testing Loss/Accuracy    = 0.037/98.800
# ############################################################
# Epoch 62 : Training Loss/Accuracy   = 0.110/98.883
# Epoch 62 : Validation Loss/Accuracy = 0.045/98.500
# Epoch 62 : Testing Loss/Accuracy    = 0.038/98.730
# ############################################################
# Epoch 63 : Training Loss/Accuracy   = 0.108/98.967
# Epoch 63 : Validation Loss/Accuracy = 0.043/98.733
# Epoch 63 : Testing Loss/Accuracy    = 0.036/98.740
# ############################################################
# Epoch 64 : Training Loss/Accuracy   = 0.109/98.930
# Epoch 64 : Validation Loss/Accuracy = 0.042/98.700
# Epoch 64 : Testing Loss/Accuracy    = 0.038/98.770
# ############################################################
# Epoch 65 : Training Loss/Accuracy   = 0.108/98.937
# Epoch 65 : Validation Loss/Accuracy = 0.042/98.633
# Epoch 65 : Testing Loss/Accuracy    = 0.037/98.750
# ############################################################
# Epoch 66 : Training Loss/Accuracy   = 0.108/98.933
# Epoch 66 : Validation Loss/Accuracy = 0.042/98.650
# Epoch 66 : Testing Loss/Accuracy    = 0.036/98.810
# ############################################################
# Epoch 67 : Training Loss/Accuracy   = 0.106/98.948
# Epoch 67 : Validation Loss/Accuracy = 0.041/98.700
# Epoch 67 : Testing Loss/Accuracy    = 0.037/98.700
# ############################################################
# Epoch 68 : Training Loss/Accuracy   = 0.112/98.952
# Epoch 68 : Validation Loss/Accuracy = 0.041/98.633
# Epoch 68 : Testing Loss/Accuracy    = 0.037/98.770
# ############################################################
# Epoch 69 : Training Loss/Accuracy   = 0.110/98.974
# Epoch 69 : Validation Loss/Accuracy = 0.041/98.633
# Epoch 69 : Testing Loss/Accuracy    = 0.036/98.800
# ############################################################
# Epoch 70 : Training Loss/Accuracy   = 0.107/98.919
# Epoch 70 : Validation Loss/Accuracy = 0.042/98.683
# Epoch 70 : Testing Loss/Accuracy    = 0.037/98.810
# ############################################################
# Epoch 71 : Training Loss/Accuracy   = 0.107/98.998
# Epoch 71 : Validation Loss/Accuracy = 0.041/98.667
# Epoch 71 : Testing Loss/Accuracy    = 0.036/98.760
# ############################################################
# Epoch 72 : Training Loss/Accuracy   = 0.107/98.959
# Epoch 72 : Validation Loss/Accuracy = 0.040/98.783
# Epoch 72 : Testing Loss/Accuracy    = 0.036/98.790
# ############################################################
# Epoch 73 : Training Loss/Accuracy   = 0.106/98.969
# Epoch 73 : Validation Loss/Accuracy = 0.042/98.633
# Epoch 73 : Testing Loss/Accuracy    = 0.036/98.790
# ############################################################
# Epoch 74 : Training Loss/Accuracy   = 0.103/98.872
# Epoch 74 : Validation Loss/Accuracy = 0.046/98.550
# Epoch 74 : Testing Loss/Accuracy    = 0.038/98.790
# ############################################################
# Epoch 75 : Training Loss/Accuracy   = 0.107/98.963
# Epoch 75 : Validation Loss/Accuracy = 0.043/98.633
# Epoch 75 : Testing Loss/Accuracy    = 0.036/98.800
# ############################################################
# Epoch 76 : Training Loss/Accuracy   = 0.105/98.989
# Epoch 76 : Validation Loss/Accuracy = 0.041/98.717
# Epoch 76 : Testing Loss/Accuracy    = 0.036/98.710
# ############################################################
# Epoch 77 : Training Loss/Accuracy   = 0.102/99.011
# Epoch 77 : Validation Loss/Accuracy = 0.040/98.667
# Epoch 77 : Testing Loss/Accuracy    = 0.035/98.770
# ############################################################
# Epoch 78 : Training Loss/Accuracy   = 0.105/99.009
# Epoch 78 : Validation Loss/Accuracy = 0.040/98.633
# Epoch 78 : Testing Loss/Accuracy    = 0.035/98.790
# ############################################################
# Epoch 79 : Training Loss/Accuracy   = 0.103/99.013
# Epoch 79 : Validation Loss/Accuracy = 0.041/98.733
# Epoch 79 : Testing Loss/Accuracy    = 0.036/98.870
# ############################################################
# Epoch 80 : Training Loss/Accuracy   = 0.103/99.033
# Epoch 80 : Validation Loss/Accuracy = 0.040/98.717
# Epoch 80 : Testing Loss/Accuracy    = 0.035/98.810
# ############################################################
# Epoch 81 : Training Loss/Accuracy   = 0.104/99.013
# Epoch 81 : Validation Loss/Accuracy = 0.042/98.667
# Epoch 81 : Testing Loss/Accuracy    = 0.035/98.940
# ############################################################
# Epoch 82 : Training Loss/Accuracy   = 0.101/99.024
# Epoch 82 : Validation Loss/Accuracy = 0.040/98.717
# Epoch 82 : Testing Loss/Accuracy    = 0.034/98.850
# ############################################################
# Stopping early!

# %%
plot_model_accuracies(model, show=[1,2,3])
plot_model_losses(model, show=[1,2,3])
train_Yhat = model.predict(train_X)
valid_Yhat = model.predict(valid_X)
test_Yhat = model.predict(test_X)
train_acc = get_accuracy(train_Yhat, train_Y)
print("Train Accuracy:      %.2f%%" % (train_acc))
valid_acc = get_accuracy(valid_Yhat, valid_Y)
print("Validation Accuracy: %.2f%%" % (valid_acc))
test_acc = get_accuracy(test_Yhat, test_Y)
print("Test Accuracy:       %.2f%%" % (test_acc))
plot_confusion(test_Yhat, test_Y)
# Out:
# Train Accuracy:      99.02%
# Validation Accuracy: 98.72%
# Test Accuracy:       98.85%

# %%
model = CNN(n_channels, height, width, n_classes, dropout=0.5)
model.optimize([train_X, train_Y], [valid_X, valid_Y], [test_X, test_Y], mbatch_size=1024)
# Out:
# Epoch 0 : Training Loss/Accuracy   = 2.140/71.635
# Epoch 0 : Validation Loss/Accuracy = 1.180/71.300
# Epoch 0 : Testing Loss/Accuracy    = 1.169/72.240
# ############################################################
# Epoch 1 : Training Loss/Accuracy   = 1.277/86.691
# Epoch 1 : Validation Loss/Accuracy = 0.539/86.650
# Epoch 1 : Testing Loss/Accuracy    = 0.518/87.790
# ############################################################
# Epoch 2 : Training Loss/Accuracy   = 0.938/90.319
# Epoch 2 : Validation Loss/Accuracy = 0.380/90.317
# Epoch 2 : Testing Loss/Accuracy    = 0.357/91.050
# ############################################################
# Epoch 3 : Training Loss/Accuracy   = 0.791/92.859
# Epoch 3 : Validation Loss/Accuracy = 0.289/92.950
# Epoch 3 : Testing Loss/Accuracy    = 0.267/93.720
# ############################################################
# Epoch 4 : Training Loss/Accuracy   = 0.713/93.989
# Epoch 4 : Validation Loss/Accuracy = 0.251/94.183
# Epoch 4 : Testing Loss/Accuracy    = 0.229/94.630
# ############################################################
# Epoch 5 : Training Loss/Accuracy   = 0.656/94.435
# Epoch 5 : Validation Loss/Accuracy = 0.217/94.533
# Epoch 5 : Testing Loss/Accuracy    = 0.197/95.080
# ############################################################
# Epoch 6 : Training Loss/Accuracy   = 0.618/94.750
# Epoch 6 : Validation Loss/Accuracy = 0.203/94.850
# Epoch 6 : Testing Loss/Accuracy    = 0.181/95.390
# ############################################################
# Epoch 7 : Training Loss/Accuracy   = 0.594/94.939
# Epoch 7 : Validation Loss/Accuracy = 0.192/94.800
# Epoch 7 : Testing Loss/Accuracy    = 0.172/95.330
# ############################################################
# Epoch 8 : Training Loss/Accuracy   = 0.567/95.159
# Epoch 8 : Validation Loss/Accuracy = 0.182/95.267
# Epoch 8 : Testing Loss/Accuracy    = 0.163/95.930
# ############################################################
# Epoch 9 : Training Loss/Accuracy   = 0.554/95.600
# Epoch 9 : Validation Loss/Accuracy = 0.162/95.450
# Epoch 9 : Testing Loss/Accuracy    = 0.144/96.270
# ############################################################
# Epoch 10 : Training Loss/Accuracy   = 0.542/95.674
# Epoch 10 : Validation Loss/Accuracy = 0.171/95.633
# Epoch 10 : Testing Loss/Accuracy    = 0.149/96.120
# ############################################################
# Epoch 11 : Training Loss/Accuracy   = 0.524/95.656
# Epoch 11 : Validation Loss/Accuracy = 0.161/95.433
# Epoch 11 : Testing Loss/Accuracy    = 0.141/96.090
# ############################################################
# Epoch 12 : Training Loss/Accuracy   = 0.518/96.026
# Epoch 12 : Validation Loss/Accuracy = 0.151/95.817
# Epoch 12 : Testing Loss/Accuracy    = 0.131/96.480
# ############################################################
# Epoch 13 : Training Loss/Accuracy   = 0.505/95.993
# Epoch 13 : Validation Loss/Accuracy = 0.150/95.967
# Epoch 13 : Testing Loss/Accuracy    = 0.129/96.470
# ############################################################
# Epoch 14 : Training Loss/Accuracy   = 0.504/96.161
# Epoch 14 : Validation Loss/Accuracy = 0.144/95.900
# Epoch 14 : Testing Loss/Accuracy    = 0.126/96.650
# ############################################################
# Epoch 15 : Training Loss/Accuracy   = 0.497/96.165
# Epoch 15 : Validation Loss/Accuracy = 0.144/95.750
# Epoch 15 : Testing Loss/Accuracy    = 0.126/96.610
# ############################################################
# Epoch 16 : Training Loss/Accuracy   = 0.485/96.285
# Epoch 16 : Validation Loss/Accuracy = 0.137/96.117
# Epoch 16 : Testing Loss/Accuracy    = 0.121/96.700
# ############################################################
# Epoch 17 : Training Loss/Accuracy   = 0.487/96.333
# Epoch 17 : Validation Loss/Accuracy = 0.140/95.900
# Epoch 17 : Testing Loss/Accuracy    = 0.121/96.700
# ############################################################
# Epoch 18 : Training Loss/Accuracy   = 0.479/96.467
# Epoch 18 : Validation Loss/Accuracy = 0.130/96.133
# Epoch 18 : Testing Loss/Accuracy    = 0.113/96.810
# ############################################################
# Epoch 19 : Training Loss/Accuracy   = 0.471/96.383
# Epoch 19 : Validation Loss/Accuracy = 0.131/96.017
# Epoch 19 : Testing Loss/Accuracy    = 0.115/96.760
# ############################################################
# Epoch 20 : Training Loss/Accuracy   = 0.469/96.511
# Epoch 20 : Validation Loss/Accuracy = 0.133/96.050
# Epoch 20 : Testing Loss/Accuracy    = 0.114/96.830
# ############################################################
# Epoch 21 : Training Loss/Accuracy   = 0.468/96.454
# Epoch 21 : Validation Loss/Accuracy = 0.130/96.117
# Epoch 21 : Testing Loss/Accuracy    = 0.111/96.830
# ############################################################
# Epoch 22 : Training Loss/Accuracy   = 0.453/96.428
# Epoch 22 : Validation Loss/Accuracy = 0.129/96.167
# Epoch 22 : Testing Loss/Accuracy    = 0.113/96.810
# ############################################################
# Epoch 23 : Training Loss/Accuracy   = 0.454/96.574
# Epoch 23 : Validation Loss/Accuracy = 0.126/96.350
# Epoch 23 : Testing Loss/Accuracy    = 0.110/96.950
# ############################################################
# Epoch 24 : Training Loss/Accuracy   = 0.457/96.578
# Epoch 24 : Validation Loss/Accuracy = 0.122/96.383
# Epoch 24 : Testing Loss/Accuracy    = 0.106/96.910
# ############################################################
# Epoch 25 : Training Loss/Accuracy   = 0.455/96.669
# Epoch 25 : Validation Loss/Accuracy = 0.124/96.300
# Epoch 25 : Testing Loss/Accuracy    = 0.108/96.900
# ############################################################
# Epoch 26 : Training Loss/Accuracy   = 0.449/96.604
# Epoch 26 : Validation Loss/Accuracy = 0.124/96.333
# Epoch 26 : Testing Loss/Accuracy    = 0.107/97.080
# ############################################################
# Epoch 27 : Training Loss/Accuracy   = 0.442/96.694
# Epoch 27 : Validation Loss/Accuracy = 0.122/96.317
# Epoch 27 : Testing Loss/Accuracy    = 0.108/96.860
# ############################################################
# Epoch 28 : Training Loss/Accuracy   = 0.448/96.698
# Epoch 28 : Validation Loss/Accuracy = 0.124/96.183
# Epoch 28 : Testing Loss/Accuracy    = 0.106/96.970
# ############################################################
# Epoch 29 : Training Loss/Accuracy   = 0.444/96.743
# Epoch 29 : Validation Loss/Accuracy = 0.120/96.367
# Epoch 29 : Testing Loss/Accuracy    = 0.105/96.990
# ############################################################
# Epoch 30 : Training Loss/Accuracy   = 0.439/96.724
# Epoch 30 : Validation Loss/Accuracy = 0.118/96.333
# Epoch 30 : Testing Loss/Accuracy    = 0.104/97.060
# ############################################################
# Epoch 31 : Training Loss/Accuracy   = 0.434/96.770
# Epoch 31 : Validation Loss/Accuracy = 0.118/96.200
# Epoch 31 : Testing Loss/Accuracy    = 0.103/96.950
# ############################################################
# Epoch 32 : Training Loss/Accuracy   = 0.439/96.793
# Epoch 32 : Validation Loss/Accuracy = 0.117/96.400
# Epoch 32 : Testing Loss/Accuracy    = 0.103/96.900
# ############################################################
# Epoch 33 : Training Loss/Accuracy   = 0.426/96.852
# Epoch 33 : Validation Loss/Accuracy = 0.115/96.433
# Epoch 33 : Testing Loss/Accuracy    = 0.101/97.100
# ############################################################
# Epoch 34 : Training Loss/Accuracy   = 0.434/96.857
# Epoch 34 : Validation Loss/Accuracy = 0.114/96.600
# Epoch 34 : Testing Loss/Accuracy    = 0.102/97.120
# ############################################################
# Epoch 35 : Training Loss/Accuracy   = 0.425/96.843
# Epoch 35 : Validation Loss/Accuracy = 0.114/96.533
# Epoch 35 : Testing Loss/Accuracy    = 0.101/97.070
# ############################################################
# Epoch 36 : Training Loss/Accuracy   = 0.428/96.889
# Epoch 36 : Validation Loss/Accuracy = 0.114/96.550
# Epoch 36 : Testing Loss/Accuracy    = 0.100/97.110
# ############################################################
# Epoch 37 : Training Loss/Accuracy   = 0.426/96.863
# Epoch 37 : Validation Loss/Accuracy = 0.113/96.517
# Epoch 37 : Testing Loss/Accuracy    = 0.098/97.080
# ############################################################
# Epoch 38 : Training Loss/Accuracy   = 0.420/96.876
# Epoch 38 : Validation Loss/Accuracy = 0.112/96.567
# Epoch 38 : Testing Loss/Accuracy    = 0.098/97.140
# ############################################################
# Epoch 39 : Training Loss/Accuracy   = 0.426/96.980
# Epoch 39 : Validation Loss/Accuracy = 0.111/96.650
# Epoch 39 : Testing Loss/Accuracy    = 0.097/97.160
# ############################################################
# Epoch 40 : Training Loss/Accuracy   = 0.425/96.867
# Epoch 40 : Validation Loss/Accuracy = 0.111/96.617
# Epoch 40 : Testing Loss/Accuracy    = 0.099/97.090
# ############################################################
# Epoch 41 : Training Loss/Accuracy   = 0.421/96.930
# Epoch 41 : Validation Loss/Accuracy = 0.111/96.517
# Epoch 41 : Testing Loss/Accuracy    = 0.098/97.160
# ############################################################
# Epoch 42 : Training Loss/Accuracy   = 0.417/96.943
# Epoch 42 : Validation Loss/Accuracy = 0.111/96.667
# Epoch 42 : Testing Loss/Accuracy    = 0.097/97.230
# ############################################################
# Epoch 43 : Training Loss/Accuracy   = 0.419/97.011
# Epoch 43 : Validation Loss/Accuracy = 0.110/96.650
# Epoch 43 : Testing Loss/Accuracy    = 0.097/97.240
# ############################################################
# Epoch 44 : Training Loss/Accuracy   = 0.416/97.102
# Epoch 44 : Validation Loss/Accuracy = 0.109/96.800
# Epoch 44 : Testing Loss/Accuracy    = 0.093/97.310
# ############################################################
# Epoch 45 : Training Loss/Accuracy   = 0.415/96.944
# Epoch 45 : Validation Loss/Accuracy = 0.108/96.583
# Epoch 45 : Testing Loss/Accuracy    = 0.097/97.120
# ############################################################
# Epoch 46 : Training Loss/Accuracy   = 0.408/97.061
# Epoch 46 : Validation Loss/Accuracy = 0.105/96.683
# Epoch 46 : Testing Loss/Accuracy    = 0.093/97.310
# ############################################################
# Epoch 47 : Training Loss/Accuracy   = 0.413/97.119
# Epoch 47 : Validation Loss/Accuracy = 0.108/96.600
# Epoch 47 : Testing Loss/Accuracy    = 0.093/97.350
# ############################################################
# Epoch 48 : Training Loss/Accuracy   = 0.414/97.050
# Epoch 48 : Validation Loss/Accuracy = 0.104/96.767
# Epoch 48 : Testing Loss/Accuracy    = 0.092/97.350
# ############################################################
# Epoch 49 : Training Loss/Accuracy   = 0.408/97.063
# Epoch 49 : Validation Loss/Accuracy = 0.105/96.733
# Epoch 49 : Testing Loss/Accuracy    = 0.090/97.350
# ############################################################
# Epoch 50 : Training Loss/Accuracy   = 0.410/97.083
# Epoch 50 : Validation Loss/Accuracy = 0.105/96.783
# Epoch 50 : Testing Loss/Accuracy    = 0.091/97.340
# ############################################################
# Epoch 51 : Training Loss/Accuracy   = 0.401/97.107
# Epoch 51 : Validation Loss/Accuracy = 0.105/96.767
# Epoch 51 : Testing Loss/Accuracy    = 0.090/97.330
# ############################################################
# Epoch 52 : Training Loss/Accuracy   = 0.403/97.161
# Epoch 52 : Validation Loss/Accuracy = 0.104/96.817
# Epoch 52 : Testing Loss/Accuracy    = 0.091/97.360
# ############################################################
# Epoch 53 : Training Loss/Accuracy   = 0.404/97.198
# Epoch 53 : Validation Loss/Accuracy = 0.103/96.817
# Epoch 53 : Testing Loss/Accuracy    = 0.089/97.430
# ############################################################
# Epoch 54 : Training Loss/Accuracy   = 0.404/97.222
# Epoch 54 : Validation Loss/Accuracy = 0.101/96.850
# Epoch 54 : Testing Loss/Accuracy    = 0.087/97.450
# ############################################################
# Epoch 55 : Training Loss/Accuracy   = 0.398/97.178
# Epoch 55 : Validation Loss/Accuracy = 0.102/96.933
# Epoch 55 : Testing Loss/Accuracy    = 0.090/97.440
# ############################################################
# Epoch 56 : Training Loss/Accuracy   = 0.399/97.167
# Epoch 56 : Validation Loss/Accuracy = 0.102/96.900
# Epoch 56 : Testing Loss/Accuracy    = 0.090/97.340
# ############################################################
# Epoch 57 : Training Loss/Accuracy   = 0.396/97.243
# Epoch 57 : Validation Loss/Accuracy = 0.102/96.867
# Epoch 57 : Testing Loss/Accuracy    = 0.087/97.430
# ############################################################
# Epoch 58 : Training Loss/Accuracy   = 0.396/97.170
# Epoch 58 : Validation Loss/Accuracy = 0.103/96.850
# Epoch 58 : Testing Loss/Accuracy    = 0.089/97.350
# ############################################################
# Epoch 59 : Training Loss/Accuracy   = 0.396/97.241
# Epoch 59 : Validation Loss/Accuracy = 0.100/96.850
# Epoch 59 : Testing Loss/Accuracy    = 0.087/97.510
# ############################################################
# Epoch 60 : Training Loss/Accuracy   = 0.397/97.035
# Epoch 60 : Validation Loss/Accuracy = 0.104/96.733
# Epoch 60 : Testing Loss/Accuracy    = 0.092/97.270
# ############################################################
# Epoch 61 : Training Loss/Accuracy   = 0.403/97.252
# Epoch 61 : Validation Loss/Accuracy = 0.099/96.983
# Epoch 61 : Testing Loss/Accuracy    = 0.087/97.550
# ############################################################
# Epoch 62 : Training Loss/Accuracy   = 0.394/97.322
# Epoch 62 : Validation Loss/Accuracy = 0.100/96.850
# Epoch 62 : Testing Loss/Accuracy    = 0.086/97.570
# ############################################################
# Epoch 63 : Training Loss/Accuracy   = 0.393/97.206
# Epoch 63 : Validation Loss/Accuracy = 0.101/96.867
# Epoch 63 : Testing Loss/Accuracy    = 0.088/97.470
# ############################################################
# Epoch 64 : Training Loss/Accuracy   = 0.391/97.287
# Epoch 64 : Validation Loss/Accuracy = 0.102/96.833
# Epoch 64 : Testing Loss/Accuracy    = 0.086/97.500
# ############################################################
# Epoch 65 : Training Loss/Accuracy   = 0.394/97.287
# Epoch 65 : Validation Loss/Accuracy = 0.101/96.850
# Epoch 65 : Testing Loss/Accuracy    = 0.086/97.590
# ############################################################
# Epoch 66 : Training Loss/Accuracy   = 0.392/97.326
# Epoch 66 : Validation Loss/Accuracy = 0.099/96.900
# Epoch 66 : Testing Loss/Accuracy    = 0.085/97.710
# ############################################################
# Epoch 67 : Training Loss/Accuracy   = 0.388/97.376
# Epoch 67 : Validation Loss/Accuracy = 0.098/96.933
# Epoch 67 : Testing Loss/Accuracy    = 0.083/97.670
# ############################################################
# Epoch 68 : Training Loss/Accuracy   = 0.395/97.337
# Epoch 68 : Validation Loss/Accuracy = 0.098/96.933
# Epoch 68 : Testing Loss/Accuracy    = 0.084/97.670
# ############################################################
# Epoch 69 : Training Loss/Accuracy   = 0.390/97.315
# Epoch 69 : Validation Loss/Accuracy = 0.100/96.900
# Epoch 69 : Testing Loss/Accuracy    = 0.086/97.610
# ############################################################
# Epoch 70 : Training Loss/Accuracy   = 0.389/97.344
# Epoch 70 : Validation Loss/Accuracy = 0.097/96.967
# Epoch 70 : Testing Loss/Accuracy    = 0.084/97.750
# ############################################################
# Epoch 71 : Training Loss/Accuracy   = 0.386/97.259
# Epoch 71 : Validation Loss/Accuracy = 0.098/97.017
# Epoch 71 : Testing Loss/Accuracy    = 0.085/97.570
# ############################################################
# Epoch 72 : Training Loss/Accuracy   = 0.389/97.319
# Epoch 72 : Validation Loss/Accuracy = 0.098/97.150
# Epoch 72 : Testing Loss/Accuracy    = 0.085/97.630
# ############################################################
# Epoch 73 : Training Loss/Accuracy   = 0.386/97.391
# Epoch 73 : Validation Loss/Accuracy = 0.096/97.183
# Epoch 73 : Testing Loss/Accuracy    = 0.084/97.630
# ############################################################
# Epoch 74 : Training Loss/Accuracy   = 0.390/97.343
# Epoch 74 : Validation Loss/Accuracy = 0.097/96.983
# Epoch 74 : Testing Loss/Accuracy    = 0.083/97.790
# ############################################################
# Epoch 75 : Training Loss/Accuracy   = 0.388/97.330
# Epoch 75 : Validation Loss/Accuracy = 0.096/97.050
# Epoch 75 : Testing Loss/Accuracy    = 0.084/97.590
# ############################################################
# Epoch 76 : Training Loss/Accuracy   = 0.383/97.324
# Epoch 76 : Validation Loss/Accuracy = 0.097/96.833
# Epoch 76 : Testing Loss/Accuracy    = 0.083/97.650
# ############################################################
# Epoch 77 : Training Loss/Accuracy   = 0.382/97.346
# Epoch 77 : Validation Loss/Accuracy = 0.095/97.150
# Epoch 77 : Testing Loss/Accuracy    = 0.083/97.760
# ############################################################
# Epoch 78 : Training Loss/Accuracy   = 0.389/97.396
# Epoch 78 : Validation Loss/Accuracy = 0.095/97.183
# Epoch 78 : Testing Loss/Accuracy    = 0.081/97.660
# ############################################################
# Epoch 79 : Training Loss/Accuracy   = 0.383/97.398
# Epoch 79 : Validation Loss/Accuracy = 0.096/97.017
# Epoch 79 : Testing Loss/Accuracy    = 0.081/97.690
# ############################################################
# Epoch 80 : Training Loss/Accuracy   = 0.379/97.411
# Epoch 80 : Validation Loss/Accuracy = 0.096/97.000
# Epoch 80 : Testing Loss/Accuracy    = 0.082/97.800
# ############################################################
# Epoch 81 : Training Loss/Accuracy   = 0.381/97.361
# Epoch 81 : Validation Loss/Accuracy = 0.095/96.967
# Epoch 81 : Testing Loss/Accuracy    = 0.082/97.710
# ############################################################
# Epoch 82 : Training Loss/Accuracy   = 0.375/97.430
# Epoch 82 : Validation Loss/Accuracy = 0.094/97.183
# Epoch 82 : Testing Loss/Accuracy    = 0.081/97.800
# ############################################################
# Epoch 83 : Training Loss/Accuracy   = 0.378/97.456
# Epoch 83 : Validation Loss/Accuracy = 0.095/97.117
# Epoch 83 : Testing Loss/Accuracy    = 0.081/97.680
# ############################################################
# Stopping early!

# %%
plot_model_accuracies(model, show=[1,2,3])
plot_model_losses(model, show=[1,2,3])
train_Yhat = model.predict(train_X)
valid_Yhat = model.predict(valid_X)
test_Yhat = model.predict(test_X)
train_acc = get_accuracy(train_Yhat, train_Y)
print("Train Accuracy:      %.2f%%" % (train_acc))
valid_acc = get_accuracy(valid_Yhat, valid_Y)
print("Validation Accuracy: %.2f%%" % (valid_acc))
test_acc = get_accuracy(test_Yhat, test_Y)
print("Test Accuracy:       %.2f%%" % (test_acc))
plot_confusion(test_Yhat, test_Y)
# Out:
# Train Accuracy:      97.46%
# Validation Accuracy: 97.12%
# Test Accuracy:       97.68%

# %%
model = CNN(n_channels, height, width, n_classes, dropout=0.75)
model.optimize([train_X, train_Y], [valid_X, valid_Y], [test_X, test_Y], mbatch_size=1024)
# Out:
# Epoch 0 : Training Loss/Accuracy   = 2.324/11.204
# Epoch 0 : Validation Loss/Accuracy = 2.300/11.533
# Epoch 0 : Testing Loss/Accuracy    = 2.301/11.350
# ############################################################
# Epoch 1 : Training Loss/Accuracy   = 2.292/13.224
# Epoch 1 : Validation Loss/Accuracy = 2.270/13.500
# Epoch 1 : Testing Loss/Accuracy    = 2.271/13.890
# ############################################################
# Epoch 2 : Training Loss/Accuracy   = 2.233/46.970
# Epoch 2 : Validation Loss/Accuracy = 2.094/47.383
# Epoch 2 : Testing Loss/Accuracy    = 2.090/47.950
# ############################################################
# Epoch 3 : Training Loss/Accuracy   = 2.117/55.489
# Epoch 3 : Validation Loss/Accuracy = 1.838/55.417
# Epoch 3 : Testing Loss/Accuracy    = 1.827/56.470
# ############################################################
# Epoch 4 : Training Loss/Accuracy   = 2.000/65.407
# Epoch 4 : Validation Loss/Accuracy = 1.606/64.667
# Epoch 4 : Testing Loss/Accuracy    = 1.595/65.830
# ############################################################
# Epoch 5 : Training Loss/Accuracy   = 1.875/63.585
# Epoch 5 : Validation Loss/Accuracy = 1.451/62.967
# Epoch 5 : Testing Loss/Accuracy    = 1.436/63.480
# ############################################################
# Epoch 6 : Training Loss/Accuracy   = 1.745/69.415
# Epoch 6 : Validation Loss/Accuracy = 1.210/68.550
# Epoch 6 : Testing Loss/Accuracy    = 1.191/69.360
# ############################################################
# Epoch 7 : Training Loss/Accuracy   = 1.660/71.481
# Epoch 7 : Validation Loss/Accuracy = 1.121/71.150
# Epoch 7 : Testing Loss/Accuracy    = 1.100/71.230
# ############################################################
# Epoch 8 : Training Loss/Accuracy   = 1.595/67.548
# Epoch 8 : Validation Loss/Accuracy = 1.151/67.817
# Epoch 8 : Testing Loss/Accuracy    = 1.129/67.680
# ############################################################
# Epoch 9 : Training Loss/Accuracy   = 1.548/72.444
# Epoch 9 : Validation Loss/Accuracy = 1.050/72.600
# Epoch 9 : Testing Loss/Accuracy    = 1.025/72.550
# ############################################################
# Epoch 10 : Training Loss/Accuracy   = 1.518/75.970
# Epoch 10 : Validation Loss/Accuracy = 0.978/75.250
# Epoch 10 : Testing Loss/Accuracy    = 0.947/76.310
# ############################################################
# Epoch 11 : Training Loss/Accuracy   = 1.489/76.146
# Epoch 11 : Validation Loss/Accuracy = 0.958/76.000
# Epoch 11 : Testing Loss/Accuracy    = 0.928/76.700
# ############################################################
# Epoch 12 : Training Loss/Accuracy   = 1.468/74.207
# Epoch 12 : Validation Loss/Accuracy = 0.983/74.700
# Epoch 12 : Testing Loss/Accuracy    = 0.957/74.560
# ############################################################
# Epoch 13 : Training Loss/Accuracy   = 1.453/73.507
# Epoch 13 : Validation Loss/Accuracy = 0.969/73.867
# Epoch 13 : Testing Loss/Accuracy    = 0.940/74.160
# ############################################################
# Epoch 14 : Training Loss/Accuracy   = 1.447/74.120
# Epoch 14 : Validation Loss/Accuracy = 0.962/74.417
# Epoch 14 : Testing Loss/Accuracy    = 0.934/74.740
# ############################################################
# Epoch 15 : Training Loss/Accuracy   = 1.427/77.824
# Epoch 15 : Validation Loss/Accuracy = 0.886/77.717
# Epoch 15 : Testing Loss/Accuracy    = 0.857/78.370
# ############################################################
# Epoch 16 : Training Loss/Accuracy   = 1.406/79.376
# Epoch 16 : Validation Loss/Accuracy = 0.848/79.333
# Epoch 16 : Testing Loss/Accuracy    = 0.817/80.220
# ############################################################
# Epoch 17 : Training Loss/Accuracy   = 1.393/74.970
# Epoch 17 : Validation Loss/Accuracy = 0.903/75.217
# Epoch 17 : Testing Loss/Accuracy    = 0.874/75.680
# ############################################################
# Epoch 18 : Training Loss/Accuracy   = 1.394/79.987
# Epoch 18 : Validation Loss/Accuracy = 0.804/79.517
# Epoch 18 : Testing Loss/Accuracy    = 0.773/80.730
# ############################################################
# Epoch 19 : Training Loss/Accuracy   = 1.380/76.519
# Epoch 19 : Validation Loss/Accuracy = 0.875/76.567
# Epoch 19 : Testing Loss/Accuracy    = 0.846/77.220
# ############################################################
# Epoch 20 : Training Loss/Accuracy   = 1.367/77.402
# Epoch 20 : Validation Loss/Accuracy = 0.842/77.250
# Epoch 20 : Testing Loss/Accuracy    = 0.813/78.010
# ############################################################
# Epoch 21 : Training Loss/Accuracy   = 1.360/78.141
# Epoch 21 : Validation Loss/Accuracy = 0.836/78.133
# Epoch 21 : Testing Loss/Accuracy    = 0.806/78.900
# ############################################################
# Epoch 22 : Training Loss/Accuracy   = 1.350/80.615
# Epoch 22 : Validation Loss/Accuracy = 0.785/80.533
# Epoch 22 : Testing Loss/Accuracy    = 0.754/81.360
# ############################################################
# Epoch 23 : Training Loss/Accuracy   = 1.345/80.176
# Epoch 23 : Validation Loss/Accuracy = 0.782/79.950
# Epoch 23 : Testing Loss/Accuracy    = 0.750/81.010
# ############################################################
# Epoch 24 : Training Loss/Accuracy   = 1.335/79.046
# Epoch 24 : Validation Loss/Accuracy = 0.797/78.650
# Epoch 24 : Testing Loss/Accuracy    = 0.768/79.660
# ############################################################
# Epoch 25 : Training Loss/Accuracy   = 1.342/78.007
# Epoch 25 : Validation Loss/Accuracy = 0.830/78.067
# Epoch 25 : Testing Loss/Accuracy    = 0.801/78.710
# ############################################################
# Epoch 26 : Training Loss/Accuracy   = 1.314/80.967
# Epoch 26 : Validation Loss/Accuracy = 0.755/80.850
# Epoch 26 : Testing Loss/Accuracy    = 0.724/81.790
# ############################################################
# Epoch 27 : Training Loss/Accuracy   = 1.311/81.641
# Epoch 27 : Validation Loss/Accuracy = 0.748/81.900
# Epoch 27 : Testing Loss/Accuracy    = 0.717/82.450
# ############################################################
# Epoch 28 : Training Loss/Accuracy   = 1.303/80.630
# Epoch 28 : Validation Loss/Accuracy = 0.761/80.250
# Epoch 28 : Testing Loss/Accuracy    = 0.732/81.140
# ############################################################
# Epoch 29 : Training Loss/Accuracy   = 1.297/80.220
# Epoch 29 : Validation Loss/Accuracy = 0.757/80.333
# Epoch 29 : Testing Loss/Accuracy    = 0.727/80.770
# ############################################################
# Epoch 30 : Training Loss/Accuracy   = 1.303/81.141
# Epoch 30 : Validation Loss/Accuracy = 0.743/81.383
# Epoch 30 : Testing Loss/Accuracy    = 0.712/81.720
# ############################################################
# Epoch 31 : Training Loss/Accuracy   = 1.301/80.226
# Epoch 31 : Validation Loss/Accuracy = 0.749/80.100
# Epoch 31 : Testing Loss/Accuracy    = 0.720/80.900
# ############################################################
# Epoch 32 : Training Loss/Accuracy   = 1.298/81.091
# Epoch 32 : Validation Loss/Accuracy = 0.752/81.133
# Epoch 32 : Testing Loss/Accuracy    = 0.724/81.830
# ############################################################
# Epoch 33 : Training Loss/Accuracy   = 1.279/81.443
# Epoch 33 : Validation Loss/Accuracy = 0.729/81.717
# Epoch 33 : Testing Loss/Accuracy    = 0.702/82.050
# ############################################################
# Epoch 34 : Training Loss/Accuracy   = 1.278/82.424
# Epoch 34 : Validation Loss/Accuracy = 0.710/82.950
# Epoch 34 : Testing Loss/Accuracy    = 0.681/83.130
# ############################################################
# Epoch 35 : Training Loss/Accuracy   = 1.274/81.659
# Epoch 35 : Validation Loss/Accuracy = 0.699/81.767
# Epoch 35 : Testing Loss/Accuracy    = 0.669/82.500
# ############################################################
# Epoch 36 : Training Loss/Accuracy   = 1.274/82.037
# Epoch 36 : Validation Loss/Accuracy = 0.704/82.217
# Epoch 36 : Testing Loss/Accuracy    = 0.677/82.760
# ############################################################
# Epoch 37 : Training Loss/Accuracy   = 1.280/83.948
# Epoch 37 : Validation Loss/Accuracy = 0.679/84.367
# Epoch 37 : Testing Loss/Accuracy    = 0.650/84.920
# ############################################################
# Epoch 38 : Training Loss/Accuracy   = 1.284/80.013
# Epoch 38 : Validation Loss/Accuracy = 0.744/80.050
# Epoch 38 : Testing Loss/Accuracy    = 0.716/80.850
# ############################################################
# Epoch 39 : Training Loss/Accuracy   = 1.271/82.581
# Epoch 39 : Validation Loss/Accuracy = 0.702/82.667
# Epoch 39 : Testing Loss/Accuracy    = 0.672/83.290
# ############################################################
# Epoch 40 : Training Loss/Accuracy   = 1.265/83.572
# Epoch 40 : Validation Loss/Accuracy = 0.685/83.850
# Epoch 40 : Testing Loss/Accuracy    = 0.658/84.410
# ############################################################
# Epoch 41 : Training Loss/Accuracy   = 1.264/82.478
# Epoch 41 : Validation Loss/Accuracy = 0.700/82.583
# Epoch 41 : Testing Loss/Accuracy    = 0.671/83.290
# ############################################################
# Epoch 42 : Training Loss/Accuracy   = 1.261/79.420
# Epoch 42 : Validation Loss/Accuracy = 0.748/79.417
# Epoch 42 : Testing Loss/Accuracy    = 0.717/80.380
# ############################################################
# Epoch 43 : Training Loss/Accuracy   = 1.259/83.224
# Epoch 43 : Validation Loss/Accuracy = 0.688/83.450
# Epoch 43 : Testing Loss/Accuracy    = 0.661/83.900
# ############################################################
# Epoch 44 : Training Loss/Accuracy   = 1.256/83.907
# Epoch 44 : Validation Loss/Accuracy = 0.672/84.100
# Epoch 44 : Testing Loss/Accuracy    = 0.644/84.780
# ############################################################
# Epoch 45 : Training Loss/Accuracy   = 1.264/81.257
# Epoch 45 : Validation Loss/Accuracy = 0.728/81.350
# Epoch 45 : Testing Loss/Accuracy    = 0.698/82.080
# ############################################################
# Epoch 46 : Training Loss/Accuracy   = 1.246/81.444
# Epoch 46 : Validation Loss/Accuracy = 0.710/81.483
# Epoch 46 : Testing Loss/Accuracy    = 0.682/82.090
# ############################################################
# Epoch 47 : Training Loss/Accuracy   = 1.255/82.950
# Epoch 47 : Validation Loss/Accuracy = 0.689/82.967
# Epoch 47 : Testing Loss/Accuracy    = 0.662/83.710
# ############################################################
# Stopping early!

# %%
plot_model_accuracies(model, show=[1,2,3], ylim=[60, 100.1])
plot_model_losses(model, show=[1,2,3])
train_Yhat = model.predict(train_X)
valid_Yhat = model.predict(valid_X)
test_Yhat = model.predict(test_X)
train_acc = get_accuracy(train_Yhat, train_Y)
print("Train Accuracy:      %.2f%%" % (train_acc))
valid_acc = get_accuracy(valid_Yhat, valid_Y)
print("Validation Accuracy: %.2f%%" % (valid_acc))
test_acc = get_accuracy(test_Yhat, test_Y)
print("Test Accuracy:       %.2f%%" % (test_acc))
plot_confusion(test_Yhat, test_Y)
# Out:
# Train Accuracy:      82.95%
# Validation Accuracy: 82.97%
# Test Accuracy:       83.71%
