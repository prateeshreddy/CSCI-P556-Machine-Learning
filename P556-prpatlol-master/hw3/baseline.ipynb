# %% [markdown]
# # Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np
import sys
import torch
import torchvision
from sklearn.metrics import confusion_matrix
from sklearn.decomposition import PCA

# %%
def get_device(use_gpu=True):
    return torch.device("cuda" if torch.cuda.is_available() and use_gpu else "cpu")

def to_device(items, device):
    return [item.to(device) for item in items]

def to_tensor(items, types):
    tensors = []
    for i in range(len(items)):
        if isinstance(items[i], torch.Tensor):
            tensors += items[i]
        elif isinstance(items[i], np.ndarray):
            if isinstance(types, list):
                tensors += [torch.tensor(items[i], dtype=types[i])]
            else:
                tensors += [torch.tensor(items[i], dtype=types)]
        else:
            raise NotImplementedError()
    return tensors

def to_ndarray(items):
    ndarrays = []
    for item in items:
        if isinstance(item, torch.Tensor):
            ndarrays += [item.detach().cpu().numpy()]
        elif isinstance(item, np.ndarray):
            ndarrays += [item]
        elif isinstance(item, list):
            ndarrays += [np.array(item)]
        else:
            raise NotImplementedError()
    return ndarrays

def get_accuracy(Yhat, Y):
    if isinstance(Yhat, torch.Tensor) and isinstance(Y, torch.Tensor):
        _, preds = Yhat.max(dim=1)
        n_correct = preds.eq(Y).sum().item()
    elif isinstance(Yhat, np.ndarray) and isinstance(Y, np.ndarray):
        preds = np.argmax(Yhat, axis=-1)
        n_correct = len(np.where(preds == Y)[0])
    return n_correct / len(Y) * 100

def get_confusion(Yhat, Y):
    preds = np.argmax(Yhat, axis=-1)
    return confusion_matrix(Y, preds)

def plot_model_accuracies(model, show=[1,2,3], ylim=[95, 100.1]):
    plt.figure(figsize=(15,10))
    if 1 in show:
        plt.plot(model.train_accs, color="k", label="training")
    if 2 in show:
        plt.plot(model.valid_accs, color="r", label="validation")
    if 3 in show:
        plt.plot(model.test_accs, color="g", label="testing")
    plt.ylabel("Accuracy")
    plt.xlabel("Epoch")
    plt.ylim(ylim[0], ylim[1])
    plt.xlim(-1, len(model.train_accs)+1)
    plt.legend()
    plt.show()
    plt.close()
    
def plot_model_losses(model, show=[1,2,3]):
    plt.figure(figsize=(15,10))
    if 1 in show:
        plt.plot(model.train_losses, color="k", label="training")
    if 2 in show:
        plt.plot(model.valid_losses, color="r", label="validation")
    if 3 in show:
        plt.plot(model.test_losses, color="g", label="testing")
    plt.ylabel("Cross Entropy Loss")
    plt.xlabel("Epoch")
    plt.xlim(-1, len(model.train_accs)+1)
    plt.legend()
    plt.show()
    plt.close()
    
def plot_confusion(Yhat, Y):
    n_classes = np.unique(Y).shape[0]
    mat = get_confusion(test_Yhat, test_Y)
    plt.figure(figsize=(10,10))
    plt.imshow(mat, extent=[-0.5, n_classes-1+0.5, -0.5, n_classes-1+0.5], origin="upper")
    plt.ylabel("True Class")
    plt.title("Predicted Class")
    plt.yticks(np.arange(n_classes))
    plt.xticks(np.arange(n_classes))
    for j in range(mat.shape[0]):
        for k in range(mat.shape[1]):
            plt.text(j, k, mat[mat.shape[0]-k-1,j], ha="center", va="center")
    plt.show()
    plt.close()

act_func_map = {
    "relu": torch.nn.functional.relu, 
    "tanh": torch.nn.functional.tanh, 
    "sigmoid": torch.sigmoid, 
    "identity": lambda x:x,
    "log_softmax": torch.nn.functional.log_softmax,
}
opt_func_map = {
    "sgd": torch.optim.SGD, 
    "adam": torch.optim.Adam
}
init_func_map = {
    "constant": torch.nn.init.constant_,
    "normal": torch.nn.init.normal_, 
    "xavier": torch.nn.init.xavier_normal_, 
    "kaiming": torch.nn.init.kaiming_normal_,
}
loss_func_map = {
    "mae": torch.nn.L1Loss, 
    "mse": torch.nn.MSELoss, 
    "smooth_mae": torch.nn.SmoothL1Loss,
    "nll": torch.nn.NLLLoss,
}

# %%
train = torchvision.datasets.MNIST(
    "data",
    train=True,
    download=True
)
test = torchvision.datasets.MNIST(
    "data",
    train=False,
    download=True
)
train_X = train.data.numpy()
train_Y = train.targets.numpy()
np.random.seed(123)
selection = np.random.choice(train_X.shape[0], size=train_X.shape[0]//10, replace=False)
valid_X = train_X[selection,:]
valid_Y = train_Y[selection]
train_X = np.delete(train_X, selection, axis=0)
train_Y = np.delete(train_Y, selection, axis=0)
test_X = test.data.numpy()
test_Y = test.targets.numpy()
train_X = np.reshape(train_X, (train_X.shape[0], 1, train_X.shape[1], train_X.shape[2]))
valid_X = np.reshape(valid_X, (valid_X.shape[0], 1, valid_X.shape[1], valid_X.shape[2]))
test_X = np.reshape(test_X, (test_X.shape[0], 1, test_X.shape[1], test_X.shape[2]))
print(train_X.shape)
print(train_Y.shape)
print(valid_X.shape)
print(valid_Y.shape)
print(test_X.shape)
print(test_Y.shape)
train_X = (train_X / 255 - 0.5) * 2
valid_X = (valid_X / 255 - 0.5) * 2
test_X = (test_X / 255 - 0.5) * 2
n_channels, height, width = train_X.shape[1], train_X.shape[2], train_X.shape[3]
n_classes = len(np.unique(train_Y))
# Out:
# (54000, 1, 28, 28)
# (54000,)
# (6000, 1, 28, 28)
# (6000,)
# (10000, 1, 28, 28)
# (10000,)

# %%
class CNN(torch.nn.Module):
    
    def __init__(self, n_channels, height, width, n_responses):
        super(CNN, self).__init__()
        in_width, in_width, = height, width
        in_channels, out_channels = n_channels, 12
        kernel_size, stride = (5, 5), (2, 2)
        self.layer_1 = torch.nn.Conv2d(in_channels, out_channels, kernel_size, stride)
        in_width, in_height = self.get_conv2d_output_heightwidth(in_channels, out_channels, kernel_size, stride)
        in_channels, out_channels = out_channels, 12
        kernel_size, stride = (5, 5), (2, 2)
        self.layer_2 = torch.nn.Conv2d(in_channels, out_channels, kernel_size, stride)
        in_width, in_height = self.get_conv2d_output_heightwidth(in_channels, out_channels, kernel_size, stride)
        in_channels = out_channels
        self.layer_3 = torch.nn.Flatten()
        self.layer_4 = torch.nn.Linear(in_channels*in_width*in_height, 30)
        self.layer_5 = torch.nn.Linear(30, n_responses)
        
    def forward(self, X):
        a = X
        z = self.layer_1(a)
        a = act_func_map["relu"](z)
        z = self.layer_2(a)
        a = act_func_map["relu"](z)
        z = self.layer_3(a)
        a = act_func_map["identity"](z)
        z = self.layer_4(a)
        a = act_func_map["relu"](z)
        z = self.layer_5(a)
        a = act_func_map["log_softmax"](z, dim=1)
        return a
    
    def optimize(self, train, valid=None, test=None, lr=0.05, mo=0.9, early_stop_epochs=10, n_epochs=100, mbatch_size=256, 
                 loss="nll", opt="sgd", batch_shuf_seed=1, init="xavier", init_seed=1):
        torch.cuda.empty_cache()
        device = get_device()
        self = to_device([self], device)[0]
        train = to_device(to_tensor(train, [torch.float, torch.long]), device)
        train_X, train_Y = train[0], train[1]
        if valid is not None:
            valid = to_device(to_tensor(valid, [torch.float, torch.long]), device)
            valid_X, valid_Y = valid[0], valid[1]
        if test is not None:
            test = to_device(to_tensor(test, [torch.float, torch.long]), device)
            test_X, test_Y = test[0], test[1]
        # Initialize loss, optimizer, and parameters
        self.crit = loss_func_map[loss]()
        if opt == "adam":
            self.opt = opt_func_map[opt](self.parameters(), lr=lr, betas=(mo, 0.999))
        if opt == "sgd":
            self.opt = opt_func_map[opt](self.parameters(), lr=lr, momentum=mo)
        self.init_params(init, init_seed)
        # Commence optimization
        n_mbatches = train_X.shape[0] // mbatch_size
        if batch_shuf_seed > -1:
            np.random.seed(batch_shuf_seed)
        self.train_losses, self.valid_losses, self.test_losses = [], [], []
        self.train_accs, self.valid_accs, self.test_accs = [], [], []
        min_valid_loss, max_valid_acc = sys.float_info.max, sys.float_info.min
        n_plateau_epochs = 0
        for epoch in range(n_epochs+1):
            selection = np.random.choice(train_X.shape[0], size=train_X.shape[0], replace=False)
            train_loss = 0
            self.train()
            # Step through minibatches
            for mbatch in range(n_mbatches):
                start = mbatch * mbatch_size
                end = (mbatch + 1) * mbatch_size
                mbatch_loss = self.crit(self(train_X[selection[start:end]]), train_Y[selection[start:end]])
                # Gradient descent step
                self.opt.zero_grad()
                mbatch_loss.backward()
                self.opt.step()
                train_loss += mbatch_loss.item()
            train_loss /= n_mbatches
            self.eval()
            train_acc = get_accuracy(self(train_X), train_Y)
            print("Epoch %d : Training Loss/Accuracy   = %.3f/%.3f" % (epoch, train_loss, train_acc))
            self.train_losses += [train_loss]
            self.train_accs += [train_acc]
            if valid is not None:
                valid_Yhat = self(valid_X)
                valid_loss = self.crit(valid_Yhat, valid_Y).item()
                valid_acc = get_accuracy(valid_Yhat, valid_Y)
                print("Epoch %d : Validation Loss/Accuracy = %.3f/%.3f" % (epoch, valid_loss, valid_acc))
                self.valid_losses += [valid_loss]
                self.valid_accs += [valid_acc]
                if valid_acc <= max_valid_acc:
                    n_plateau_epochs += 1
                else:
                    n_plateau_epochs = 0
                    max_valid_acc = valid_acc
            if test is not None:
                test_Yhat = self(test_X)
                test_loss = self.crit(test_Yhat, test_Y).item()
                test_acc = get_accuracy(test_Yhat, test_Y)
                print("Epoch %d : Testing Loss/Accuracy    = %.3f/%.3f" % (epoch, test_loss, test_acc))
                self.test_losses += [test_loss]
                self.test_accs += [test_acc]
            for param_group in self.opt.param_groups:
                param_group["lr"] = lr * 0.9**(epoch//10)
            print("############################################################")
            if n_plateau_epochs >= early_stop_epochs:
                print("Stopping early!")
                break
        device = get_device(False)
        self = to_device([self], device)[0]
        train = to_ndarray(train)
        if valid is not None:
            valid = to_ndarray(valid)
        if test is not None:
            test = to_ndarray(test)
            
    def predict(self, X):
        self.eval()
        device = get_device()
        self = to_device([self], device)[0]
        X = to_device(to_tensor([X], [torch.float]), device)[0]
        Yhat = self(X)
        device = get_device(False)
        self = to_device([self], device)[0]
        data = to_ndarray([X, Yhat])
        X, Yhat = data[0], data[1]
        return Yhat
    
    def init_params(self, init, seed=-1):
        if seed > -1:
            torch.manual_seed(seed)
        for name, param in self.named_parameters():
            if "bias" in name:
                init_func_map["constant"](param, 0.0)
            elif "weight" in name:
                init_func_map[init](param)
    
    def get_conv2d_output_heightwidth(self, H_in, W_in, kernel_size, stride, padding=(0, 0), dilation=(1, 1)):
        H_out = int((H_in + 2 * padding[0] - dilation[0] * (kernel_size[0] - 1) - 1) / stride[0] + 1)
        W_out = int((W_in + 2 * padding[1] - dilation[1] * (kernel_size[1] - 1) - 1) / stride[1] + 1)
        return H_out, W_out

# %%
model = CNN(n_channels, height, width, n_classes)
model.optimize([train_X, train_Y], [valid_X, valid_Y], [test_X, test_Y], mbatch_size=1024)
# Out:
# Epoch 0 : Training Loss/Accuracy   = 1.213/89.237
# Epoch 0 : Validation Loss/Accuracy = 0.344/89.083
# Epoch 0 : Testing Loss/Accuracy    = 0.331/89.410
# ############################################################
# Epoch 1 : Training Loss/Accuracy   = 0.259/94.087
# Epoch 1 : Validation Loss/Accuracy = 0.192/94.383
# Epoch 1 : Testing Loss/Accuracy    = 0.183/94.350
# ############################################################
# Epoch 2 : Training Loss/Accuracy   = 0.174/95.472
# Epoch 2 : Validation Loss/Accuracy = 0.142/95.783
# Epoch 2 : Testing Loss/Accuracy    = 0.137/95.530
# ############################################################
# Epoch 3 : Training Loss/Accuracy   = 0.136/96.600
# Epoch 3 : Validation Loss/Accuracy = 0.113/96.850
# Epoch 3 : Testing Loss/Accuracy    = 0.109/96.670
# ############################################################
# Epoch 4 : Training Loss/Accuracy   = 0.110/97.085
# Epoch 4 : Validation Loss/Accuracy = 0.100/97.033
# Epoch 4 : Testing Loss/Accuracy    = 0.093/97.020
# ############################################################
# Epoch 5 : Training Loss/Accuracy   = 0.094/97.411
# Epoch 5 : Validation Loss/Accuracy = 0.094/97.167
# Epoch 5 : Testing Loss/Accuracy    = 0.084/97.330
# ############################################################
# Epoch 6 : Training Loss/Accuracy   = 0.082/97.720
# Epoch 6 : Validation Loss/Accuracy = 0.086/97.300
# Epoch 6 : Testing Loss/Accuracy    = 0.075/97.640
# ############################################################
# Epoch 7 : Training Loss/Accuracy   = 0.076/97.891
# Epoch 7 : Validation Loss/Accuracy = 0.081/97.500
# Epoch 7 : Testing Loss/Accuracy    = 0.069/97.730
# ############################################################
# Epoch 8 : Training Loss/Accuracy   = 0.072/98.076
# Epoch 8 : Validation Loss/Accuracy = 0.073/97.733
# Epoch 8 : Testing Loss/Accuracy    = 0.066/97.950
# ############################################################
# Epoch 9 : Training Loss/Accuracy   = 0.065/98.152
# Epoch 9 : Validation Loss/Accuracy = 0.074/97.817
# Epoch 9 : Testing Loss/Accuracy    = 0.063/98.080
# ############################################################
# Epoch 10 : Training Loss/Accuracy   = 0.064/98.159
# Epoch 10 : Validation Loss/Accuracy = 0.073/97.783
# Epoch 10 : Testing Loss/Accuracy    = 0.065/97.880
# ############################################################
# Epoch 11 : Training Loss/Accuracy   = 0.054/98.407
# Epoch 11 : Validation Loss/Accuracy = 0.068/97.800
# Epoch 11 : Testing Loss/Accuracy    = 0.062/98.120
# ############################################################
# Epoch 12 : Training Loss/Accuracy   = 0.053/98.580
# Epoch 12 : Validation Loss/Accuracy = 0.065/97.933
# Epoch 12 : Testing Loss/Accuracy    = 0.058/98.190
# ############################################################
# Epoch 13 : Training Loss/Accuracy   = 0.049/98.550
# Epoch 13 : Validation Loss/Accuracy = 0.066/98.000
# Epoch 13 : Testing Loss/Accuracy    = 0.053/98.260
# ############################################################
# Epoch 14 : Training Loss/Accuracy   = 0.047/98.793
# Epoch 14 : Validation Loss/Accuracy = 0.062/98.067
# Epoch 14 : Testing Loss/Accuracy    = 0.051/98.350
# ############################################################
# Epoch 15 : Training Loss/Accuracy   = 0.045/98.730
# Epoch 15 : Validation Loss/Accuracy = 0.059/98.183
# Epoch 15 : Testing Loss/Accuracy    = 0.049/98.470
# ############################################################
# Epoch 16 : Training Loss/Accuracy   = 0.044/98.739
# Epoch 16 : Validation Loss/Accuracy = 0.064/98.167
# Epoch 16 : Testing Loss/Accuracy    = 0.053/98.370
# ############################################################
# Epoch 17 : Training Loss/Accuracy   = 0.040/98.909
# Epoch 17 : Validation Loss/Accuracy = 0.058/98.233
# Epoch 17 : Testing Loss/Accuracy    = 0.049/98.450
# ############################################################
# Epoch 18 : Training Loss/Accuracy   = 0.038/98.828
# Epoch 18 : Validation Loss/Accuracy = 0.060/98.150
# Epoch 18 : Testing Loss/Accuracy    = 0.051/98.440
# ############################################################
# Epoch 19 : Training Loss/Accuracy   = 0.037/98.774
# Epoch 19 : Validation Loss/Accuracy = 0.064/97.933
# Epoch 19 : Testing Loss/Accuracy    = 0.052/98.320
# ############################################################
# Epoch 20 : Training Loss/Accuracy   = 0.037/99.056
# Epoch 20 : Validation Loss/Accuracy = 0.053/98.517
# Epoch 20 : Testing Loss/Accuracy    = 0.044/98.530
# ############################################################
# Epoch 21 : Training Loss/Accuracy   = 0.034/99.039
# Epoch 21 : Validation Loss/Accuracy = 0.054/98.267
# Epoch 21 : Testing Loss/Accuracy    = 0.046/98.470
# ############################################################
# Epoch 22 : Training Loss/Accuracy   = 0.032/99.107
# Epoch 22 : Validation Loss/Accuracy = 0.053/98.417
# Epoch 22 : Testing Loss/Accuracy    = 0.044/98.590
# ############################################################
# Epoch 23 : Training Loss/Accuracy   = 0.031/99.078
# Epoch 23 : Validation Loss/Accuracy = 0.055/98.300
# Epoch 23 : Testing Loss/Accuracy    = 0.046/98.490
# ############################################################
# Epoch 24 : Training Loss/Accuracy   = 0.031/99.135
# Epoch 24 : Validation Loss/Accuracy = 0.055/98.350
# Epoch 24 : Testing Loss/Accuracy    = 0.043/98.690
# ############################################################
# Epoch 25 : Training Loss/Accuracy   = 0.029/99.106
# Epoch 25 : Validation Loss/Accuracy = 0.053/98.500
# Epoch 25 : Testing Loss/Accuracy    = 0.044/98.590
# ############################################################
# Epoch 26 : Training Loss/Accuracy   = 0.028/99.246
# Epoch 26 : Validation Loss/Accuracy = 0.050/98.483
# Epoch 26 : Testing Loss/Accuracy    = 0.042/98.660
# ############################################################
# Epoch 27 : Training Loss/Accuracy   = 0.026/99.294
# Epoch 27 : Validation Loss/Accuracy = 0.051/98.500
# Epoch 27 : Testing Loss/Accuracy    = 0.041/98.690
# ############################################################
# Epoch 28 : Training Loss/Accuracy   = 0.026/99.294
# Epoch 28 : Validation Loss/Accuracy = 0.051/98.483
# Epoch 28 : Testing Loss/Accuracy    = 0.043/98.720
# ############################################################
# Epoch 29 : Training Loss/Accuracy   = 0.025/99.385
# Epoch 29 : Validation Loss/Accuracy = 0.052/98.467
# Epoch 29 : Testing Loss/Accuracy    = 0.043/98.580
# ############################################################
# Epoch 30 : Training Loss/Accuracy   = 0.023/99.407
# Epoch 30 : Validation Loss/Accuracy = 0.052/98.533
# Epoch 30 : Testing Loss/Accuracy    = 0.040/98.770
# ############################################################
# Epoch 31 : Training Loss/Accuracy   = 0.022/99.274
# Epoch 31 : Validation Loss/Accuracy = 0.056/98.450
# Epoch 31 : Testing Loss/Accuracy    = 0.047/98.520
# ############################################################
# Epoch 32 : Training Loss/Accuracy   = 0.022/99.444
# Epoch 32 : Validation Loss/Accuracy = 0.053/98.450
# Epoch 32 : Testing Loss/Accuracy    = 0.042/98.750
# ############################################################
# Epoch 33 : Training Loss/Accuracy   = 0.021/99.207
# Epoch 33 : Validation Loss/Accuracy = 0.061/98.233
# Epoch 33 : Testing Loss/Accuracy    = 0.048/98.410
# ############################################################
# Epoch 34 : Training Loss/Accuracy   = 0.021/99.474
# Epoch 34 : Validation Loss/Accuracy = 0.052/98.600
# Epoch 34 : Testing Loss/Accuracy    = 0.043/98.600
# ############################################################
# Epoch 35 : Training Loss/Accuracy   = 0.020/99.506
# Epoch 35 : Validation Loss/Accuracy = 0.054/98.500
# Epoch 35 : Testing Loss/Accuracy    = 0.044/98.690
# ############################################################
# Epoch 36 : Training Loss/Accuracy   = 0.018/99.337
# Epoch 36 : Validation Loss/Accuracy = 0.057/98.550
# Epoch 36 : Testing Loss/Accuracy    = 0.046/98.580
# ############################################################
# Epoch 37 : Training Loss/Accuracy   = 0.018/99.504
# Epoch 37 : Validation Loss/Accuracy = 0.052/98.567
# Epoch 37 : Testing Loss/Accuracy    = 0.044/98.760
# ############################################################
# Epoch 38 : Training Loss/Accuracy   = 0.018/99.459
# Epoch 38 : Validation Loss/Accuracy = 0.054/98.433
# Epoch 38 : Testing Loss/Accuracy    = 0.046/98.610
# ############################################################
# Epoch 39 : Training Loss/Accuracy   = 0.017/99.585
# Epoch 39 : Validation Loss/Accuracy = 0.051/98.600
# Epoch 39 : Testing Loss/Accuracy    = 0.042/98.810
# ############################################################
# Epoch 40 : Training Loss/Accuracy   = 0.016/99.580
# Epoch 40 : Validation Loss/Accuracy = 0.052/98.567
# Epoch 40 : Testing Loss/Accuracy    = 0.045/98.780
# ############################################################
# Epoch 41 : Training Loss/Accuracy   = 0.016/99.659
# Epoch 41 : Validation Loss/Accuracy = 0.052/98.550
# Epoch 41 : Testing Loss/Accuracy    = 0.043/98.700
# ############################################################
# Epoch 42 : Training Loss/Accuracy   = 0.015/99.604
# Epoch 42 : Validation Loss/Accuracy = 0.051/98.583
# Epoch 42 : Testing Loss/Accuracy    = 0.045/98.760
# ############################################################
# Epoch 43 : Training Loss/Accuracy   = 0.014/99.581
# Epoch 43 : Validation Loss/Accuracy = 0.056/98.517
# Epoch 43 : Testing Loss/Accuracy    = 0.047/98.610
# ############################################################
# Epoch 44 : Training Loss/Accuracy   = 0.014/99.667
# Epoch 44 : Validation Loss/Accuracy = 0.054/98.483
# Epoch 44 : Testing Loss/Accuracy    = 0.045/98.790
# ############################################################
# Stopping early!

# %%
plot_model_accuracies(model, show=[1,2,3])
plot_model_losses(model, show=[1,2,3])
train_Yhat = model.predict(train_X)
valid_Yhat = model.predict(valid_X)
test_Yhat = model.predict(test_X)
train_acc = get_accuracy(train_Yhat, train_Y)
print("Train Accuracy:      %.2f%%" % (train_acc))
valid_acc = get_accuracy(valid_Yhat, valid_Y)
print("Validation Accuracy: %.2f%%" % (valid_acc))
test_acc = get_accuracy(test_Yhat, test_Y)
print("Test Accuracy:       %.2f%%" % (test_acc))
plot_confusion(test_Yhat, test_Y)
# Out:
# Train Accuracy:      99.67%
# Validation Accuracy: 98.48%
# Test Accuracy:       98.79%
